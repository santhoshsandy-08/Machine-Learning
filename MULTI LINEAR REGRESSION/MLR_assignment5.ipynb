# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the data

# %%
data=pd.read_csv('Toyotacorolla.csv',encoding='latin1')
data
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
data.shape
# Out:
# (1436, 38)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
data.describe()
# Out:
#                 Id         Price    Age_08_04    Mfg_Month     Mfg_Year  \
# count  1436.000000   1436.000000  1436.000000  1436.000000  1436.000000
# mean    721.555014  10730.824513    55.947075     5.548747  1999.625348
# std     416.476890   3626.964585    18.599988     3.354085     1.540722
# min       1.000000   4350.000000     1.000000     1.000000  1998.000000
# 25%     361.750000   8450.000000    44.000000     3.000000  1998.000000
# 50%     721.500000   9900.000000    61.000000     5.000000  1999.000000
# 75%    1081.250000  11950.000000    70.000000     8.000000  2001.000000
# max    1442.000000  32500.000000    80.000000    12.000000  2004.000000
#
#                   KM           HP    Met_Color    Automatic           cc  ...  \
# count    1436.000000  1436.000000  1436.000000  1436.000000   1436.00000  ...
# mean    68533.259749   101.502089     0.674791     0.055710   1576.85585  ...
# std     37506.448872    14.981080     0.468616     0.229441    424.38677  ...
# ...

# %%
toyota=data[['Price','Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]

# %%
toyota
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
toyota.shape
# Out:
# (1436, 9)

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
toyota.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
toyota[toyota.duplicated()]
# Out:
#      Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 113  24950          8  13253  116  2000      5      5            234    1320

# %%
toyota.drop_duplicates(inplace=True)
toyota
# Out:
# C:\Users\santh\AppData\Local\Temp\ipykernel_23724\2473051644.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   toyota.drop_duplicates(inplace=True)
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# ...

# %%
toyota.reset_index(drop=True,inplace=True)

# %%
toyota
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1430   7500         69  20544   86  1300      3      5             69    1025
# 1431  10845         72  19000   86  1300      3      5             69    1015
# 1432   8500         71  17016   86  1300      3      5             69    1015
# 1433   7250         70  16916   86  1300      3      5             69    1015
# 1434   6950         76      1  110  1600      5      5             19    1114
#
# [1435 rows x 9 columns]

# %%
toyota.isnull()
# Out:
#       Price  Age_08_04     KM     HP     cc  Doors  Gears  Quarterly_Tax  \
# 0     False      False  False  False  False  False  False          False
# 1     False      False  False  False  False  False  False          False
# 2     False      False  False  False  False  False  False          False
# 3     False      False  False  False  False  False  False          False
# 4     False      False  False  False  False  False  False          False
# ...     ...        ...    ...    ...    ...    ...    ...            ...
# 1430  False      False  False  False  False  False  False          False
# 1431  False      False  False  False  False  False  False          False
# 1432  False      False  False  False  False  False  False          False
# 1433  False      False  False  False  False  False  False          False
# 1434  False      False  False  False  False  False  False          False
#
#       Weight
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...

# %%
toyota.isnull().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
toyota.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876273 -0.569420  0.314134  0.124375  0.183604
# Age_08_04     -0.876273   1.000000  0.504575 -0.155293 -0.096549 -0.146929
# KM            -0.569420   0.504575  1.000000 -0.332904  0.103822 -0.035193
# HP             0.314134  -0.155293 -0.332904  1.000000  0.035207  0.091803
# cc             0.124375  -0.096549  0.103822  0.035207  1.000000  0.079254
# Doors          0.183604  -0.146929 -0.035193  0.091803  0.079254  1.000000
# Gears          0.063831  -0.005629  0.014890  0.209642  0.014732 -0.160101
# Quarterly_Tax  0.211508  -0.193319  0.283312 -0.302287  0.305982  0.107353
# Weight         0.575869  -0.466484 -0.023969  0.087143  0.335077  0.301734
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063831       0.211508  0.575869
# Age_08_04     -0.005629      -0.193319 -0.466484
# KM             0.014890       0.283312 -0.023969
# ...

# %% [markdown]
# # visualise the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(data=toyota)

# %%
plt.figure(figsize=(7,10))
sns.boxplot(data=toyota)
plt.show()

# %% [markdown]
# # preparing a model

# %%
#build the model
import statsmodels.formula.api as smf
model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=toyota).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):               0.00
# Time:                        14:32:28   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
#model parameters
model.params
# Out:
# Intercept       -5472.540368
# Age_08_04        -121.713891
# KM                 -0.020737
# HP                 31.584612
# cc                 -0.118558
# Doors              -0.920189
# Gears             597.715894
# Quarterly_Tax       3.858805
# Weight             16.855470
# dtype: float64

# %%
#model t_values
model.tvalues
# Out:
# Intercept        -3.875273
# Age_08_04       -46.551876
# KM              -16.552424
# HP               11.209719
# cc               -1.316436
# Doors            -0.023012
# Gears             3.034563
# Quarterly_Tax     2.944198
# Weight           15.760663
# dtype: float64

# %%
#model pvalues
model.pvalues
# Out:
# Intercept         1.113392e-04
# Age_08_04        1.879217e-288
# KM                1.994713e-56
# HP                5.211155e-28
# cc                1.882393e-01
# Doors             9.816443e-01
# Gears             2.452430e-03
# Quarterly_Tax     3.290363e-03
# Weight            1.031118e-51
# dtype: float64

# %% [markdown]
# # Build simple Linear Regression model

# %%
toyota_cc=smf.ols('Price~cc',data=toyota).fit()
toyota_cc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     22.52
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           2.29e-06
# Time:                        14:32:28   Log-Likelihood:                -13779.
# No. Observations:                1435   AIC:                         2.756e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9053.5368    363.894     24.880      0.000    8339.715    9767.359
# ...

# %%
toyota_Doors=smf.ols('Price~Doors',data=toyota).fit()
toyota_Doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     49.99
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           2.40e-12
# Time:                        14:32:29   Log-Likelihood:                -13765.
# No. Observations:                1435   AIC:                         2.753e+04
# Df Residuals:                    1433   BIC:                         2.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7916.1452    407.596     19.422      0.000    7116.596    8715.694
# ...

# %%
toyota_cc_Doors=smf.ols('Price~cc+Doors',data=toyota).fit()
toyota_cc_Doors.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           2.55e-15
# Time:                        14:32:29   Log-Likelihood:                -13756.
# No. Observations:                1435   AIC:                         2.752e+04
# Df Residuals:                    1432   BIC:                         2.753e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6568.3395    513.700     12.786      0.000    5560.655    7576.024
# ...

# %% [markdown]
# # calculating VIF(varianve influance factor)

# %%
rsq_Age_08_04=smf.ols('Age_08_04~KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_Age_08_04=1/(1-rsq_Age_08_04)
rsq_KM=smf.ols('KM~Age_08_04+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_KM=1/(1-rsq_KM)
rsq_HP=smf.ols('HP~KM+Age_08_04+cc+Doors+Gears+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_HP=1/(1-rsq_HP)
rsq_cc=smf.ols('cc~HP+KM+Age_08_04+Doors+Gears+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_cc=1/(1-rsq_cc)
rsq_Doors=smf.ols('Doors~cc+HP+KM+Age_08_04+Gears+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_Doors=1/(1-rsq_Doors)
rsq_Gears=smf.ols('Gears~Doors+cc+HP+KM+Age_08_04+Quarterly_Tax+Weight',data=toyota).fit().rsquared
vif_Gears=1/(1-rsq_Gears)
rsq_Quarterly_Tax=smf.ols('Quarterly_Tax~Gears+Doors+cc+HP+KM+Age_08_04+Weight',data=toyota).fit().rsquared
vif_Quarterly_Tax=1/(1-rsq_Quarterly_Tax)
rsq_Weight=smf.ols('Weight~Quarterly_Tax+Gears+Doors+cc+HP+KM+Age_08_04',data=toyota).fit().rsquared
vif_Weight=1/(1-rsq_Weight)

# %%
#VIF in Data frames
Dict={'variables':['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight'],'VIF':[vif_Age_08_04,vif_KM,vif_HP,vif_cc,vif_Doors,vif_Gears,vif_Quarterly_Tax,vif_Weight]}
toyota_Vif=pd.DataFrame(Dict)
toyota_Vif
# Out:
#        variables       VIF
# 0      Age_08_04  1.876236
# 1             KM  1.757178
# 2             HP  1.419180
# 3             cc  1.163470
# 4          Doors  1.155890
# 5          Gears  1.098843
# 6  Quarterly_Tax  2.295375
# 7         Weight  2.487180

# %% [markdown]
# # Test for Residual analysis: test for m=normality of residuals(Q-Q plot)

# %%
model.resid
# Out:
# 0      -3291.958871
# 1      -2503.800414
# 2      -2829.635210
# 3      -1455.789389
# 4      -2450.217277
#            ...
# 1430   -1294.255037
# 1431    2552.422658
# 1432      44.565598
# 1433   -1329.222041
# 1434   -3446.087526
# Length: 1435, dtype: float64

# %%
# Q-Q plot for Residuals

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title(' Q-Q plot Residuals ')
plt.show()

# %%
outliers_indices=list(np.where((model.resid>6000)|(model.resid<-6000)))

# %%
outliers_indices
# Out:
# [array([109, 146, 220, 522, 600, 959], dtype=int64)]

# %% [markdown]
# # Residuals plot homosedasticity

# %%
def get_standardized_values(values):
    return(values -values.mean())/values.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))
plt.title('Residual plot')
plt.xlabel('standardized-fitted_values')
plt.ylabel('standardized-resid_values')
plt.show()

# %% [markdown]
# # plot for regressors vs residuals

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Age_08_04',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'KM',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'HP',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'cc',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Doors',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Gears',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Quarterly_Tax',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Weight',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Detecting Influencers/Outliers

# %% [markdown]
# # cook's Distance

# %%
model_influence=model.get_influence()
(c,_)=model_influence.cooks_distance

# %% [markdown]
# # Stem plot

# %%
fig=plt.subplots(figsize=(20,10))
plt.stem(np.arange(len(toyota)),np.round(c,3))
plt.xlabel('Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# # index and value of influencer where c is more than 0.02

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 78.7295058225869)

# %% [markdown]
# # Detecting High influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model,figsize=(15,15))
plt.show()

# %%
toyota.shape
# Out:
# (1435, 9)

# %%
k=toyota.shape[1]
n=toyota.shape[0]
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %% [markdown]
# # from the above data it clear 80 is the high influence point

# %%
toyota[toyota.index.isin([80])]
# Out:
#     Price  Age_08_04     KM   HP     cc  Doors  Gears  Quarterly_Tax  Weight
# 80  18950         25  20019  110  16000      5      5            100    1180

# %%
toyota_new=toyota.drop(toyota.index[80],axis=0).reset_index()
toyota_new
# Out:
#       index  Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  \
# 0         0  13500         23  46986   90  2000      3      5            210
# 1         1  13750         23  72937   90  2000      3      5            210
# 2         2  13950         24  41711   90  2000      3      5            210
# 3         3  14950         26  48000   90  2000      3      5            210
# 4         4  13750         30  38500   90  2000      3      5            210
# ...     ...    ...        ...    ...  ...   ...    ...    ...            ...
# 1429   1430   7500         69  20544   86  1300      3      5             69
# 1430   1431  10845         72  19000   86  1300      3      5             69
# 1431   1432   8500         71  17016   86  1300      3      5             69
# 1432   1433   7250         70  16916   86  1300      3      5             69
# 1433   1434   6950         76      1  110  1600      5      5             19
#
#       Weight
# 0       1165
# 1       1165
# ...

# %%
toyota_new=toyota_new.drop(['index'],axis=1)
toyota_new
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1429   7500         69  20544   86  1300      3      5             69    1025
# 1430  10845         72  19000   86  1300      3      5             69    1015
# 1431   8500         71  17016   86  1300      3      5             69    1015
# 1432   7250         70  16916   86  1300      3      5             69    1015
# 1433   6950         76      1  110  1600      5      5             19    1114
#
# [1434 rows x 9 columns]

# %%
final_toyota=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=toyota_new).fit()
final_toyota.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):               0.00
# Time:                        14:32:43   Log-Likelihood:                -12326.
# No. Observations:                1434   AIC:                         2.467e+04
# Df Residuals:                    1425   BIC:                         2.472e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# # using sklearn

# %% [markdown]
# # split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X=toyota_new[['Age_08_04','KM','HP','cc','Doors','Gears','Quarterly_Tax','Weight']]
y=toyota_new['Price']

# %%
X
# Out:
#       Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0            23  46986   90  2000      3      5            210    1165
# 1            23  72937   90  2000      3      5            210    1165
# 2            24  41711   90  2000      3      5            210    1165
# 3            26  48000   90  2000      3      5            210    1165
# 4            30  38500   90  2000      3      5            210    1170
# ...         ...    ...  ...   ...    ...    ...            ...     ...
# 1429         69  20544   86  1300      3      5             69    1025
# 1430         72  19000   86  1300      3      5             69    1015
# 1431         71  17016   86  1300      3      5             69    1015
# 1432         70  16916   86  1300      3      5             69    1015
# 1433         76      1  110  1600      5      5             19    1114
#
# [1434 rows x 8 columns]

# %%
y
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1429     7500
# 1430    10845
# 1431     8500
# 1432     7250
# 1433     6950
# Name: Price, Length: 1434, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1147, 8), (287, 8), (1147,), (287,))

# %% [markdown]
# # build the regression modle

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_model=LinearRegression()

# %% [markdown]
# # train the model

# %%
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred=reg_model.predict(X_train)
train_pred
# Out:
# array([ 5981.34082071,  8279.17101073, 13178.11876311, ...,
#         8130.29471355, 10948.64348033, 12620.84485248])

# %%
test_pred=reg_model.predict(X_test)
test_pred
# Out:
# array([11475.31241579,  8272.19676061,  8643.23519995,  7862.8683737 ,
#        12467.41772658,  9192.10263282, 10802.13816519,  7805.56174231,
#         7127.84117914, 10442.44889895, 16307.29139741, 13048.06655337,
#         7254.37147919, 11096.4270631 ,  7229.94297158,  8058.6176291 ,
#        13618.25828664, 17971.83331123, 13112.7516839 ,  7972.40589223,
#         7695.10437501, 10844.53089015, 10139.7660332 , 12275.059681  ,
#         6477.86332035,  9880.73215947,  8362.60556007,  5418.79618699,
#         7868.93253929, 16888.84205582, 10413.01285621,  5318.98376357,
#         6738.83241368, 16564.46684297, 15667.07065004, 10635.41056546,
#         9243.89693974, 11990.89206974, 12901.69300991, 12545.35590113,
#        17509.91371308, 11107.90233544, 13192.73608617,  8631.29061369,
#        11251.42250404,  5995.96558588,  6062.07237626,  6815.15856288,
#         6838.49474021,  6942.51472372,  9872.80650406,  6733.42732421,
# ...

# %% [markdown]
# #  find the metrics for regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
train_mse=mean_squared_error(y_train,train_pred)
train_mse
# Out:
# 1701895.7434355235

# %%
test_mse=mean_squared_error(y_test,test_pred)
test_mse
# Out:
# 1793418.1839174724

# %%
train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

# %%
train_rmse,test_rmse
# Out:
# (1304.5672629019646, 1339.1856420666525)

# %% [markdown]
# # #predicting for new data

# %%
new_data=pd.DataFrame({'Age_08_04':72,'KM':18000,'HP':86,'cc':1300,'Doors':3,'Gears':5,'Quarterly_Tax':60,'Weight':1015},index=[1])
new_data
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 1         72  18000  86  1300      3      5             60    1015

# %%
reg_model.predict(new_data)
# Out:
# array([8346.15593518])

# %% [markdown]
# #*********************************************************************************************************************************

# %% [markdown]
# # Prepare a prediction model for profit of 50_startups data.
# Do transformations for getting better predictions of profit and
# make a table containing R^2 value for each prepared model.

# %% [markdown]
# # Read the data

# %%
startup=pd.read_csv('50_Startups.csv')
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startup.shape
# Out:
# (50, 5)

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# # convert string into integer

# %%
startup['State']=pd.Categorical(startup['State'])
startup['State']=startup['State'].cat.codes

# %%
startup
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      2  192261.83
# 1   162597.70       151377.59        443898.53      0  191792.06
# 2   153441.51       101145.55        407934.54      1  191050.39
# 3   144372.41       118671.85        383199.62      2  182901.99
# 4   142107.34        91391.77        366168.42      1  166187.94
# 5   131876.90        99814.71        362861.36      2  156991.12
# 6   134615.46       147198.87        127716.82      0  156122.51
# 7   130298.13       145530.06        323876.68      1  155752.60
# 8   120542.52       148718.95        311613.29      2  152211.77
# 9   123334.88       108679.17        304981.62      0  149759.96
# 10  101913.08       110594.11        229160.95      1  146121.95
# 11  100671.96        91790.61        249744.55      0  144259.40
# 12   93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
startup.rename(columns={'R&D Spend':'RandD_spend','Marketing Spend':'Marketing_Spend'},inplace=True)

# %%
startup.isnull().sum()
# Out:
# RandD_spend        0
# Administration     0
# Marketing_Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
startup.corr()
# Out:
#                  RandD_spend  Administration  Marketing_Spend     State  \
# RandD_spend         1.000000        0.241955         0.724248  0.104685
# Administration      0.241955        1.000000        -0.032154  0.011847
# Marketing_Spend     0.724248       -0.032154         1.000000  0.077670
# State               0.104685        0.011847         0.077670  1.000000
# Profit              0.972900        0.200717         0.747766  0.101796
#
#                    Profit
# RandD_spend      0.972900
# Administration   0.200717
# Marketing_Spend  0.747766
# State            0.101796
# Profit           1.000000

# %% [markdown]
# # visualise the Data

# %%
sns.pairplot(startup)
plt.show()

# %% [markdown]
# # find outliers

# %%
plt.figure(figsize=(7,10))
sns.boxplot(data=startup)
plt.show()

# %% [markdown]
# # preparing the model

# %% [markdown]
# # Build the model

# %%
import statsmodels.formula.api as smf
model=smf.ols('Profit~RandD_spend+Administration+Marketing_Spend+State',data=startup).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.946
# Method:                 Least Squares   F-statistic:                     217.2
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           8.51e-29
# Time:                        14:32:50   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1061.
# Df Residuals:                      45   BIC:                             1070.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
#model parameters
model.params
# Out:
# Intercept          50142.506443
# RandD_spend            0.805760
# Administration        -0.026826
# Marketing_Spend        0.027228
# State                -22.320577
# dtype: float64

# %%
#modeltvalues
model.tvalues
# Out:
# Intercept           7.368962
# RandD_spend        17.608621
# Administration     -0.519906
# Marketing_Spend     1.636966
# State              -0.013865
# dtype: float64

# %%
#model pvalues
model.pvalues
# Out:
# Intercept          2.900008e-09
# RandD_spend        8.249206e-22
# Administration     6.056771e-01
# Marketing_Spend    1.086131e-01
# State              9.889988e-01
# dtype: float64

# %%
startup_RandD_spend=smf.ols('Profit~RandD_spend',data=startup).fit()
startup_RandD_spend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.947
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     849.8
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           3.50e-32
# Time:                        14:32:50   Log-Likelihood:                -527.44
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      48   BIC:                             1063.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4.903e+04   2537.897     19.320      0.000    4.39e+04    5.41e+04
# ...

# %%
startup_Administration=smf.ols('Profit~Administration',data=startup).fit()
startup_Administration.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     2.015
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):              0.162
# Time:                        14:32:50   Log-Likelihood:                -599.63
# No. Observations:                  50   AIC:                             1203.
# Df Residuals:                      48   BIC:                             1207.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
startup_Marketing_Spend=smf.ols('Profit~Marketing_Spend',data=startup).fit()
startup_Marketing_Spend.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     60.88
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           4.38e-10
# Time:                        14:32:50   Log-Likelihood:                -580.18
# No. Observations:                  50   AIC:                             1164.
# Df Residuals:                      48   BIC:                             1168.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
startup_State=smf.ols('Profit~State',data=startup).fit()
startup_State.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5026
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):              0.482
# Time:                        14:32:50   Log-Likelihood:                -600.39
# No. Observations:                  50   AIC:                             1205.
# Df Residuals:                      48   BIC:                             1209.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.071e+05   9005.386     11.891      0.000     8.9e+04    1.25e+05
# ...

# %%
rsq_RandD_spend=smf.ols('RandD_spend~Administration+Marketing_Spend+State',data=startup).fit().rsquared
vif_RandD_spend=1/(1-rsq_RandD_spend)
rsq_Administration=smf.ols('Administration~RandD_spend+Marketing_Spend+State',data=startup).fit().rsquared
vif_Administration=1/(1-rsq_Administration)
rsq_Marketing_Spend=smf.ols('Marketing_Spend~Administration+RandD_spend+State',data=startup).fit().rsquared
vif_Marketing_Spend=1/(1-rsq_Marketing_Spend)
rsq_State=smf.ols('State~Marketing_Spend+Administration+RandD_spend',data=startup).fit().rsquared
vif_State=1/(1-rsq_State)

# %%
#VIF in Data frames
Dict={'variables':['RandD_spend','Administration','Marketing_Spend','State'],'VIF':[vif_RandD_spend,vif_Administration,vif_Marketing_Spend,vif_State]}
startup_Vif=pd.DataFrame(Dict)
startup_Vif
# Out:
#          variables       VIF
# 0      RandD_spend  2.481178
# 1   Administration  1.175315
# 2  Marketing_Spend  2.326780
# 3            State  1.011281

# %% [markdown]
# # Test for Residual analysis: test for m=normality of residuals(Q-Q plot)

# %%
model.resid
# Out:
# 0      -240.934416
# 1      2609.393955
# 2      8899.431581
# 3      9224.499382
# 4     -5954.860630
# 5     -6570.087958
# 6     -2016.402125
# 7     -4271.004155
# 8       490.611791
# 9     -5149.346740
# 10    10611.576482
# 11     8661.886997
# 12    12446.641369
# 13     6796.378735
# 14   -16947.693104
# 15   -16297.587589
# 16    10055.036102
# 17    -4800.428034
# 18    -4748.168968
# 19     7163.632009
# 20     1811.887956
# 21    -5983.963770
# 22    -4354.693173
# 23    -1262.466061
# 24    -4788.999732
# 25     5144.849591
# 26    -4866.912270
# 27    -9377.248176
# 28     1623.265402
# 29     -767.388601
# 30      485.636602
# 31     -181.152734
# 32    -1595.336763
# 33    -1135.453688
# 34     7652.782939
# 35     5991.106571
# 36    15424.078702
# 37      307.906968
# 38    11555.779367
# 39    -2744.396769
# 40     3403.599361
# 41     2997.938430
# 42      857.718955
# 43     9616.848808
# 44      569.213149
# 45    17300.941187
# 46    -6672.246236
# ...

# %% [markdown]
# # Q-Q plot

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title(' Q-Q plot Residuals ')
plt.show()

# %% [markdown]
# # Residuals plot homosedasticity

# %%
def get_standardized_values(values):
    return(values -values.mean())/values.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
           get_standardized_values(model.resid))
plt.title('Residual plot')
plt.xlabel('standardized-fitted_values')
plt.ylabel('standardized-resid_values')
plt.show()

# %% [markdown]
# # plot for regressors vs residuals

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'RandD_spend',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Administration',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'Marketing_Spend',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig=plt.figure(figsize=(15,10))
fig=sm.graphics.plot_regress_exog(model,'State',fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Detecting Influencers/Outliers

# %% [markdown]
# # cook's cookies

# %%
model_influence=model.get_influence()
(c,_)=model_influence.cooks_distance

# %% [markdown]
# # stem plot

# %%
plt.stem(np.arange(len(startup)),np.round(c,3))
plt.xlabel('Index')
plt.ylabel('Distance')
plt.show()

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model,figsize=(15,15))
plt.show()

# %%
startup.shape
# Out:
# (50, 5)

# %%
k=toyota.shape[1]
n=toyota.shape[0]
leverage_cutoff=3*((k+1)/n)
leverage_cutoff
# Out:
# 0.020905923344947737

# %% [markdown]
# # from the above data it clear 49 is the high influence point

# %%
startup[startup.index.isin([49])]
# Out:
#     RandD_spend  Administration  Marketing_Spend  State   Profit
# 49          0.0        116983.8         45173.06      0  14681.4

# %%
startup_new=startup.drop(startup.index[49],axis=0).reset_index()
startup_new
# Out:
#     index  RandD_spend  Administration  Marketing_Spend  State     Profit
# 0       0    165349.20       136897.80        471784.10      2  192261.83
# 1       1    162597.70       151377.59        443898.53      0  191792.06
# 2       2    153441.51       101145.55        407934.54      1  191050.39
# 3       3    144372.41       118671.85        383199.62      2  182901.99
# 4       4    142107.34        91391.77        366168.42      1  166187.94
# 5       5    131876.90        99814.71        362861.36      2  156991.12
# 6       6    134615.46       147198.87        127716.82      0  156122.51
# 7       7    130298.13       145530.06        323876.68      1  155752.60
# 8       8    120542.52       148718.95        311613.29      2  152211.77
# 9       9    123334.88       108679.17        304981.62      0  149759.96
# 10     10    101913.08       110594.11        229160.95      1  146121.95
# 11     11    100671.96        91790.61        249744.55      0  144259.40
# ...

# %%
startup_new=startup_new.drop(['index'],axis=1)
startup_new
# Out:
#     RandD_spend  Administration  Marketing_Spend  State     Profit
# 0     165349.20       136897.80        471784.10      2  192261.83
# 1     162597.70       151377.59        443898.53      0  191792.06
# 2     153441.51       101145.55        407934.54      1  191050.39
# 3     144372.41       118671.85        383199.62      2  182901.99
# 4     142107.34        91391.77        366168.42      1  166187.94
# 5     131876.90        99814.71        362861.36      2  156991.12
# 6     134615.46       147198.87        127716.82      0  156122.51
# 7     130298.13       145530.06        323876.68      1  155752.60
# 8     120542.52       148718.95        311613.29      2  152211.77
# 9     123334.88       108679.17        304981.62      0  149759.96
# 10    101913.08       110594.11        229160.95      1  146121.95
# 11    100671.96        91790.61        249744.55      0  144259.40
# 12     93863.75       127320.38        249839.44      1  141585.52
# ...

# %%
final_startup=smf.ols('Profit~RandD_spend+Administration+Marketing_Spend+State',data=startup_new).fit()
final_startup.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     276.6
# Date:                Tue, 05 Sep 2023   Prob (F-statistic):           1.45e-30
# Time:                        14:32:55   Log-Likelihood:                -506.00
# No. Observations:                  49   AIC:                             1022.
# Df Residuals:                      44   BIC:                             1031.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # using sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
X=startup[['RandD_spend','Administration','Marketing_Spend','State']]
y=startup['Profit']

# %%
X
# Out:
#     RandD_spend  Administration  Marketing_Spend  State
# 0     165349.20       136897.80        471784.10      2
# 1     162597.70       151377.59        443898.53      0
# 2     153441.51       101145.55        407934.54      1
# 3     144372.41       118671.85        383199.62      2
# 4     142107.34        91391.77        366168.42      1
# 5     131876.90        99814.71        362861.36      2
# 6     134615.46       147198.87        127716.82      0
# 7     130298.13       145530.06        323876.68      1
# 8     120542.52       148718.95        311613.29      2
# 9     123334.88       108679.17        304981.62      0
# 10    101913.08       110594.11        229160.95      1
# 11    100671.96        91790.61        249744.55      0
# 12     93863.75       127320.38        249839.44      1
# 13     91992.39       135495.07        252664.93      0
# 14    119943.24       156547.42        256512.92      1
# 15    114523.61       122616.84        261776.23      2
# ...

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((40, 4), (10, 4), (40,), (10,))

# %% [markdown]
# # Build a  regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_model=LinearRegression()

# %%
#train the model

# %%
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred=reg_model.predict(X_train)
train_pred
# Out:
# array([ 62909.20345335,  73179.0488557 ,  83624.55495561, 115704.58084379,
#        150133.80642789, 109600.27231182, 115360.76003876,  99265.64447976,
#        112979.59282412, 182188.47588101, 128076.00639439, 126240.92118291,
#         97153.16096828, 187469.36954508, 158543.39790463, 100431.63494667,
#         99455.51742568, 113814.90906699, 148176.0521205 , 145783.74006912,
#        136039.91693797,  73289.72592655, 158706.75097097, 163472.35054596,
#        128328.05412682, 135487.60398876, 172588.05610596, 111992.24243259,
#         74417.8261846 , 173080.13449456,  45148.18549447,  47118.81082065,
#        154861.78682415,  99009.31588123, 114625.25796999,  52977.28345664,
#         69935.83093148, 108678.25655055,  46591.69156353, 115654.07909652])

# %%
test_pred=reg_model.predict(X_test)
test_pred
# Out:
# array([101156.3502648 , 128183.28902238,  59066.15693812,  86294.45918986,
#         96386.61354508,  69536.16070996, 191050.35382391,  90154.57395593,
#         90536.55763814,  50569.24368492])

# %% [markdown]
# #  find the metrics for regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
train_mse=mean_squared_error(y_train,train_pred)
train_mse
# Out:
# 79157119.98255321

# %%
test_mse=mean_squared_error(y_test,test_pred)
test_mse
# Out:
# 84316605.76468787

# %%
train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

# %%
train_rmse,test_rmse
# Out:
# (8897.028716518409, 9182.407405723614)

# %% [markdown]
# # predicting new data

# %%
new_data=pd.DataFrame({'RandD_spend':92000,'Administration':120000,'Marketing_Spend':30000,'State':2},index=[1])
new_data
# Out:
#    RandD_spend  Administration  Marketing_Spend  State
# 1        92000          120000            30000      2

# %%
reg_model.predict(new_data)
# Out:
# array([122883.59817593])

# %% [markdown]
# # Table containing R^2 value for each prepared model.

# %%
dframe1=pd.DataFrame(
[
    ['initial_combine_all_features',0.951],
    ['RandD_spend',0.947],
    ['Administration',0.040],
    ['Marketing_Spend',0.559],
    ['State',0.010],
    ['final_combine_all_features',0.962]
],index=[1,2,3,4,5,6],columns=['Features_Name','R_square_value'])

# %%
dframe1
# Out:
#                   Features_Name  R_square_value
# 1  initial_combine_all_features           0.951
# 2                   RandD_spend           0.947
# 3                Administration           0.040
# 4               Marketing_Spend           0.559
# 5                         State           0.010
# 6    final_combine_all_features           0.962

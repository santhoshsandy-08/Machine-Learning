# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the Data

# %%
data=pd.read_csv('Salary_Data.csv')
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
data.describe ()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
color=['#000099','#ffff00']
pal=sns.color_palette(color)
sns.heatmap(data.isnull(),cmap=pal ,annot=True)
# Out:
# <Axes: >

# %%
mean_YearsExperience=data['YearsExperience'].mean()
mean_Salary=data['Salary'].mean() 
std_YearsExperience=data['YearsExperience'].std()
std_Salary=data[ 'YearsExperience'].std() 
variance_YearsExperience=np.sqrt(std_YearsExperience) 
varaince_Salary=np.sqrt(std_Salary)
print({

'Mean_YearsExperience': mean_YearsExperience,

'Mean_Salary': mean_Salary, 
'std_YearsExperience': std_YearsExperience,

'std_Salary': std_Salary,

'Variance_YearsExperience': variance_YearsExperience,

'Variance_Salary': varaince_Salary

})
# Out:
# {'Mean_YearsExperience': 5.3133333333333335, 'Mean_Salary': 76003.0, 'std_YearsExperience': 2.8378881576627184, 'std_Salary': 2.8378881576627184, 'Variance_YearsExperience': 1.6846032641731163, 'Variance_Salary': 1.6846032641731163}

# %%
Mean_YearsExperience= 5.3133333333333335

# %%
result=np.log(Mean_YearsExperience)
print(result)
# Out:
# 1.6702193846939593

# %%
cube_root_arr=Mean_YearsExperience**(1/3)
cube_root_arr
# Out:
# 1.7449742426701742

# %%
sns.pairplot(data)

# %%
sm.qqplot(data['YearsExperience'],line='s')

# %%
sns.displot(data['Salary'])

# %%
sns.regplot(x="YearsExperience",y="Salary",data=data)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# #  step 1 visualize the Linear data

# %%
sns.scatterplot(x=data['YearsExperience'],y=data['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# # step 2 Find correlation between YearsExperience and Salary

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
color=['#000099','#ffff00']
pal=sns.color_palette(color)
sns.heatmap(data.corr(),cmap=pal)
# Out:
# <Axes: >

# %% [markdown]
# # split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x=data['YearsExperience'].values.reshape(-1,1)
y=data['Salary']

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((24, 1), (6, 1), (24,), (6,))

# %% [markdown]
# # Build the model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_model=LinearRegression()

# %% [markdown]
# # train the model

# %%
reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred=reg_model.predict(x_train)
train_pred
# Out:
# array([ 44981.60020741,  65137.8627188 ,  63218.2186701 , 104490.56571725,
#        126566.47227735,  72816.43891362,  64178.04069445,  56499.46449963,
#         68977.15081621,  56499.46449963,  54579.82045093,  93932.52344937,
#         36343.20198824, 116968.25203383,  38262.84603694,  61298.57462139,
#         64178.04069445, 109289.67583901,  83374.4811815 ,  82414.65915715,
#         53619.99842658,  40182.49008564,  91053.05737632, 101611.09964419])

# %%
test_pred=reg_model.predict(x_test)
test_pred
# Out:
# array([ 76655.72701103, 124646.82822865,  74736.08296233,  46901.24425611,
#        117928.07405818, 112169.14191207])

# %% [markdown]
# # Find the metrics fo the regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
train_mse=mean_squared_error(y_train,train_pred)
train_mse
# Out:
# 29946680.04689725

# %%
test_mse=mean_squared_error(y_test,test_pred)
test_mse
# Out:
# 40471131.10000784

# %%
train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

# %%
train_rmse,test_rmse
# Out:
# (5472.355986857695, 6361.6924713481585)

# %% [markdown]
# # Salary_hike -> Build a prediction model for Salary_hike

# %% [markdown]
# # Read the data

# %%
data1=pd.read_csv('delivery_time.csv')
data1.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
data1.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
data1.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
color=['#CB4335','#3498DB']
pal=sns.color_palette(color)
sns.heatmap(data1.isnull(),cmap=pal ,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data1)

# %%
sm.qqplot(data1['Delivery Time'],line='s')

# %%
sns.displot(data1['Sorting Time'])

# %%
sns.regplot(x="Delivery Time",y="Sorting Time",data=data1)
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %% [markdown]
# #  step 1 visualize the Linear data

# %%
sns.scatterplot(x=data1['Delivery Time'],y=data1['Sorting Time'])
# Out:
# <Axes: xlabel='Delivery Time', ylabel='Sorting Time'>

# %% [markdown]
# # step 2 Find correlation between Delivery time  and sorting time

# %%
data1.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
color=['#CB4335','#3498DB']
pal=sns.color_palette(color)
sns.heatmap(data.corr(),cmap=pal)
# Out:
# <Axes: >

# %% [markdown]
# # split the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x=data1['Delivery Time'].values.reshape(-1,1)
y=data1['Sorting Time']

# %%
x
# Out:
# array([[21.  ],
#        [13.5 ],
#        [19.75],
#        [24.  ],
#        [29.  ],
#        [15.35],
#        [19.  ],
#        [ 9.5 ],
#        [17.9 ],
#        [18.75],
#        [19.83],
#        [10.75],
#        [16.68],
#        [11.5 ],
#        [12.03],
#        [14.88],
#        [13.75],
#        [18.11],
#        [ 8.  ],
#        [17.83],
#        [21.5 ]])

# %%
y
# Out:
# 0     10
# 1      4
# 2      6
# 3      9
# 4     10
# 5      6
# 6      7
# 7      3
# 8     10
# 9      9
# 10     8
# 11     4
# 12     7
# 13     3
# 14     3
# 15     4
# 16     6
# 17     7
# 18     2
# 19     7
# 20     5
# Name: Sorting Time, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((16, 1), (5, 1), (16,), (5,))

# %% [markdown]
# # Build the model

# %%
from sklearn.linear_model import LinearRegression

# %%
reg_model=LinearRegression()

# %% [markdown]
# # Train the model

# %%
reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
train_pred=reg_model.predict(x_train)
train_pred
# Out:
# array([ 6.66031795,  4.07873094, 11.1377579 ,  7.10402821,  6.16820292,
#         3.77620121,  3.271985  ,  8.11246063,  7.00318497,  7.40655794,
#         9.12089306,  7.43882778,  4.29251862,  7.91077415,  6.63208184,
#         4.88547688])

# %%
test_pred=reg_model.predict(x_test)
test_pred
# Out:
# array([2.66692555, 5.44213158, 4.98632012, 5.63171687, 6.74502627])

# %% [markdown]
# # Find the metrics fo the regression

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
train_mse=mean_squared_error(y_train,train_pred)
train_mse
# Out:
# 2.3359948693470036

# %%
test_mse=mean_squared_error(y_test,test_pred)
test_mse
# Out:
# 0.7505448270259145

# %%
train_rmse=np.sqrt(train_mse)
test_rmse=np.sqrt(test_mse)

# %%
train_rmse,test_rmse
# Out:
# (1.5283961755209294, 0.8663399027090433)
